# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import data_util

# %% [markdown]
# # blodtrycksklass vs bmi klass

# %%
df = pd.read_csv("data\processed_cardio.csv")

_ = data_util.plot_bmi_vs_bp(df)
# Out:
# <>:1: SyntaxWarning: invalid escape sequence '\p'
# <>:1: SyntaxWarning: invalid escape sequence '\p'
# C:\Users\ludwi\AppData\Local\Temp\ipykernel_18816\462298566.py:1: SyntaxWarning: invalid escape sequence '\p'
#   df = pd.read_csv("data\processed_cardio.csv")
